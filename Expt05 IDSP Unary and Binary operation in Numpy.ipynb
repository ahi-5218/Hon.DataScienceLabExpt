# %% [markdown]
# Expt05 IDSP : Write a python program to demonstrate unary and Binary Operation in Numpy.

# %%
import numpy as np

# %%
# Unary operations
arr = np.array([1, 2, 3, 4, 5])
print("Original array:", arr)
print("Square root:", np.sqrt(arr))
print("Exponential:", np.exp(arr))
print("Logarithm:", np.log(arr))
print("Sine:", np.sin(arr))
print("Cosine:", np.cos(arr))
# Out:
# Original array: [1 2 3 4 5]
# Square root: [1.         1.41421356 1.73205081 2.         2.23606798]
# Exponential: [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591 ]
# Logarithm: [0.         0.69314718 1.09861229 1.38629436 1.60943791]
# Sine: [ 0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427]
# Cosine: [ 0.54030231 -0.41614684 -0.9899925  -0.65364362  0.28366219]

# %%
# Binary operations
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

print("\nArray 1:", arr1)
print("Array 2:", arr2)

print("Addition:", arr1 + arr2)
print("Subtraction:", arr1 - arr2)
print("Multiplication:", arr1 * arr2)
print("Division:", arr1 / arr2)
print("Modulus:", arr1 % arr2)
print("Power:", np.power(arr1, arr2))
# Out:
# Array 1: [1 2 3]
# Array 2: [4 5 6]
# Addition: [5 7 9]
# Subtraction: [-3 -3 -3]
# Multiplication: [ 4 10 18]
# Division: [0.25 0.4  0.5 ]
# Modulus: [1 2 3]
# Power: [  1  32 729]
